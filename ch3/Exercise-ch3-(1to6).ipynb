# %% [markdown]
#  <div dir="rtl" align="right">
# <b>3.1.</b> تبدیل Z را همراه با ناحیه همگرایی (ROC) برای هر یک از دنباله‌های زیر تعیین کنید.
# </div>
#
# #### (a)
# $$
# \mathcal{Z} \left[ \left(\frac{1}{2} \right)^n u[n] \right] = \sum_{n=0}^{\infty} \left(\frac{1}{2} \right)^n z^{-n} = \sum_{n=0}^{\infty} \left(\frac{1}{2z} \right)^n = \frac{1}{1 - \frac{1}{2}z^{-1}}, \quad |z| > \frac{1}{2}
# $$
#
# #### (b)
# $$
# \mathcal{Z} \left[ -\left(\frac{1}{2} \right)^n u[-n-1] \right] = -\sum_{n=-\infty}^{-1} \left(\frac{1}{2} \right)^n z^{-n} = -\sum_{n=1}^{\infty} (2z)^n
# $$
# $$
# = \frac{-2z}{1 - 2z} = \frac{1}{1 - \frac{1}{2}z^{-1}}, \quad |z| < \frac{1}{2}
# $$
#
# #### (c)
# $$
# \mathcal{Z} \left[ \left(\frac{1}{2} \right)^n u[-n] \right] = \sum_{n=-\infty}^{0} (2z)^n = \frac{1}{1 - 2z}, \quad |z| < \frac{1}{2}
# $$
#
# #### (d)
# $$
# \mathcal{Z} [\delta[n]] = z^0 = 1, \quad \text{all } z
# $$
#
# #### (e)
# $$
# \mathcal{Z} [\delta[n-1]] = z^{-1}, \quad |z| > 0
# $$
#
# #### (f)
# $$
# \mathcal{Z} [\delta[n+1]] = z^{+1}, \quad 0 \leq |z| < \infty
# $$
#
# #### (g)
# $$
# \mathcal{Z} \left[ \left(\frac{1}{2} \right)^n (u[n] - u[n-10]) \right] = \sum_{n=0}^{9} \left(\frac{1}{2z} \right)^n
# $$
# $$
# = \frac{1 - (2z)^{-10}}{1 - (2z)^{-1}}, \quad |z| > 0
# $$
# _____________
#
#
# <div dir="rtl" align="right">
# <b>3.2.</b> تبدیل Z دنباله زیر را تعیین کنید.
# </div
#
# $$
# x[n] =
# \begin{cases}
# n, & 0 \leq n \leq N-1 \\
# N, & N \leq n
# \end{cases}
# = n u[n] - (n - N) u[n - N]
# $$
#
# $$
# n \, x[n] \quad \Longleftrightarrow \quad -z \frac{d}{dz} X(z) \Rightarrow n \, u[n] \quad \Longleftrightarrow \quad -z \frac{d}{dz} \frac{1}{1 - z^{-1}}, \quad |z| > 1
# $$
#
# $$
# n \, u[n] \quad \Longleftrightarrow \quad \frac{z^{-1}}{(1 - z^{-1})^2}, \quad |z| > 1
# $$
#
# $$
# x[n - n_0] \quad \Longleftrightarrow \quad X(z) \cdot z^{-n_0} \Rightarrow (n - N) u[n - N] \quad \Longleftrightarrow \quad \frac{z^{-N-1}}{(1 - z^{-1})^2}, \quad |z| > 1
# $$
#
# <div dir="rtl" align="right">
# **بنابراین:**
# </div>
#
# $$
# X(z) = \frac{z^{-1} - z^{-N-1}}{(1 - z^{-1})^2} = \frac{z^{-1} (1 - z^{-N})}{(1 - z^{-1})^2}
# $$
# ___________
#
# <div dir="rtl" align="right">
# <b>3.3.</b> تبدیل Z هر یک از دنباله‌های زیر را تعیین کنید. پاسخ خود را همراه با ناحیه همگرایی (ROC) در صفحه Z و یک نمودار قطب-صفر ارائه دهید. تمامی مجموع‌ها را به صورت فرم بسته بیان کنید؛ مقدار آلفا می‌تواند مختلط باشد.
# </div>
#
# $$
# \textbf{(a)}
# $$
#
# $$
# x_a[n] = \alpha^{|n|}
# \quad 0 < |\alpha| < 1
# $$
#
# $$
# X_a(z) = \sum_{n=-\infty}^{-1} \alpha^{-n}z^{-n} + \sum_{n=0}^{\infty} \alpha^n z^{-n}
# $$
#
# $$
# = \sum_{n=1}^{\infty} \alpha^n z^n + \sum_{n=0}^{\infty} \alpha^n z^{-n}
# $$
#
# $$
# = \frac{\alpha z}{1 - \alpha z} + \frac{1}{1 - \alpha z^{-1}}
# $$
#
# $$
# = \frac{z(1 - \alpha^2)}{(1 - \alpha z)(z - \alpha)},
# \quad |\alpha| < |z| < \frac{1}{|\alpha|}
# $$
#
# ---
#
# $$
# \textbf{(b)}
# $$
#
# $$
# x_b[n] =
# \begin{cases}
# 1, & 0 \leq n \leq N-1 \\
# 0, & N \leq n \\
# 0, & n < 0
# \end{cases}
# $$
#
# $$
# X_b(z) = \sum_{n=0}^{N-1} z^{-n} = \frac{1 - z^{-N}}{1 - z^{-1}}
# $$
#
# $$
# = \frac{z^N - 1}{z^{N-1} (z - 1)},
# \quad z \neq 0
# $$
#
# ---
#
# $$
# \textbf{(c)}
# $$
#
# $$
# x_c[n] = x_b[n-1] * x_b[n]
# $$
#
# $$
# \Rightarrow X_c(z) = z^{-1} X_b(z) \cdot X_b(z)
# $$
#
# $$
# X_c(z) = z^{-1} \left( \frac{z^N - 1}{z^{N-1} (z - 1)} \right)^2
# $$
#
# $$
# = \frac{1}{z^{2N-1}} \left( \frac{z^N - 1}{z - 1} \right)^2,
# \quad z \neq 0, 1
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_pole_zero(poles, zeros, title):
    fig, ax = plt.subplots(figsize=(5, 5))
    ax.scatter(np.real(zeros), np.imag(zeros), s=100, marker='o', facecolors='none', edgecolors='b', label="Zeros")
    ax.scatter(np.real(poles), np.imag(poles), s=100, marker='x', color='r', label="Poles")

    unit_circle = plt.Circle((0, 0), 1, color='gray', fill=False, linestyle='dashed')
    ax.add_patch(unit_circle)

    ax.axhline(0, color='black', linewidth=1)
    ax.axvline(0, color='black', linewidth=1)

    ax.set_xlim(-1.5, 1.5)
    ax.set_ylim(-1.5, 1.5)
    ax.set_title(title)
    ax.legend()
    ax.set_aspect('equal', adjustable='datalim')

    plt.show()

# نمودار اول: X_a(z)
alpha = 0.5  # مقدار آلفا (می‌توان تغییر داد)
zeros_a = [0]  # صفرها
poles_a = [alpha, 1/alpha]  # قطب‌ها
plot_pole_zero(poles_a, zeros_a, "Pole-Zero Plot for X_a(z)")

# نمودار دوم: X_b(z)
N = 10  # مقدار N (می‌توان تغییر داد)
zeros_b = np.exp(2j * np.pi * np.arange(N) / N)  # ریشه‌های واحد
poles_b = [1] * (N - 1)  # قطب‌ها
plot_pole_zero(poles_b, zeros_b, "Pole-Zero Plot for X_b(z)")

# نمودار سوم: X_c(z)
zeros_c = np.exp(2j * np.pi * np.arange(2*N-1) / (2*N-1))  # ریشه‌های دوگانه
poles_c = [1] * (2*N-1)  # قطب‌ها
plot_pole_zero(poles_c, zeros_c, "Pole-Zero Plot for X_c(z)")
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# WARNING:matplotlib.axes._base:Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ______________
# 3.4.
# <p dir="rtl" align="justify
# style="font-size:14px; line-height:2;">
# در نظر بگیرید که تبدیل Z تابع X(z) دارای نمودار قطب-صفر مطابق شکل P3.4 است.
# <br><br>
# <b>(الف)</b> ناحیه همگرایی (ROC) تابع X(z) را تعیین کنید، با این فرض که تبدیل فوریه آن وجود دارد. در این حالت، مشخص کنید که دنباله x[n] راست‌سویه، چپ‌سویه یا دوسویه است.
# <br><br>
# <b>(ب)</b> چند دنباله دوسویه ممکن است وجود داشته باشند که نمودار قطب-صفر آن‌ها مطابق شکل P3.4 باشد؟
# <br><br>
# <b>(ج)</b> آیا ممکن است نمودار قطب-صفر در شکل P3.4 به دنباله‌ای نسبت داده شود که هم پایدار و هم علی باشد؟ اگر بله، ناحیه همگرایی مناسب را مشخص کنید.
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt

# ایجاد صفحه مختصات
fig, ax = plt.subplots(figsize=(6,6))
ax.axhline(0, color='black', linewidth=1)  # محور افقی (Re)
ax.axvline(0, color='black', linewidth=1)  # محور عمودی (Im)

# رسم دایره واحد
unit_circle = plt.Circle((0, 0), 1, color='black', fill=False, linestyle='solid', linewidth=1.5)
ax.add_patch(unit_circle)

# نقاط قطب (X)
poles = [1/3, 2, 3]
ax.scatter(poles, [0]*len(poles), marker='x', color='black', s=100, label='Poles')

# نقاط صفر (O)
zeros = [-1]
ax.scatter(zeros, [0]*len(zeros), marker='o', edgecolors='black', facecolors='white', s=100, label='Zero')

# برچسب‌های محور
ax.set_xlabel(r'$\mathbb{Re}$', fontsize=14)
ax.set_ylabel(r'$\mathbb{Im}$', fontsize=14)

# برچسب‌ها و تنظیمات
ax.text(-1.05, 0.05, '-1', fontsize=12)
ax.text(1/3 - 0.05, -0.1, r'$\frac{1}{3}$', fontsize=12)
ax.text(2 - 0.05, -0.1, '2', fontsize=12)
ax.text(3 - 0.05, -0.1, '3', fontsize=12)

# اضافه کردن توضیحات
ax.text(0.3, 1.1, 'Unit circle', fontsize=12)
ax.text(2.5, 2.5, 'z-plane', fontsize=12)
ax.text(3.5, -0.8, 'Figure P3.4', fontsize=12, fontweight='bold')

# تنظیمات نمایش
ax.set_xlim(-1.5, 3.5)
ax.set_ylim(-1.5, 1.5)
ax.set_aspect('equal')
ax.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
#  قطب-صفر تابع $X(z)$ در زیر نشان داده شده است

# %% [markdown]
# **الف)**
# برای اینکه تبدیل فوریه $x[n]$ وجود داشته باشد، تبدیل $z$ آن باید دارای ناحیه همگرایی (ROC) باشد که دایره واحد را شامل شود. بنابراین، ناحیه همگرایی به‌صورت زیر خواهد بود:
#
# $$ \frac{1}{3} < |z| < 2 $$
#
# از آنجایی که این ROC خارج از $$ \frac{1}{3} $$ قرار دارد، این قطب به یک دنباله راست‌سویه مربوط است. همچنین، چون ROC درون ۲ و ۳ قرار دارد، این قطب‌ها به دنباله چپ‌سویه مربوط می‌شوند. بنابراین، به‌طور کلی $$ x[n] $$ یک دنباله دوسویه است.
#
# ---
#
# **ب)**
# دنباله‌های دوسویه دارای ROCهایی هستند که مانند واشر (حلقه‌ای) به نظر می‌رسند. در اینجا دو حالت ممکن برای ROC وجود دارد:
#
# $$ \frac{1}{3} < |z| < 2 \quad \text{و} \quad 2 < |z| < 3 $$
#
# ---
#
# **ج)**
# ROC باید یک ناحیه متصل باشد.
# برای **پایداری**، ROC باید دایره واحد را در بر بگیرد.
# برای **علیت**، ROC باید بیرون‌ترین قطب را شامل شود.
# این شرایط با هیچ‌یک از نواحی همگرایی ممکن برای این نمودار قطب-صفر برآورده نمی‌شود.

# %%
import numpy as np
import matplotlib.pyplot as plt

# ایجاد صفحه مختصات
fig, ax = plt.subplots(figsize=(6,6))
ax.axhline(0, color='black', linewidth=1)  # محور افقی (Re)
ax.axvline(0, color='black', linewidth=1)  # محور عمودی (Im)

# رسم دایره واحد
unit_circle = plt.Circle((0, 0), 1, color='black', fill=False, linestyle='solid', linewidth=1.5)
ax.add_patch(unit_circle)

# نقاط قطب (X)
poles = [1/3, 2, 3]
ax.scatter(poles, [0]*len(poles), marker='x', color='black', s=100, label='Poles')

# نقاط صفر (O)
zeros = [-1]
ax.scatter(zeros, [0]*len(zeros), marker='o', edgecolors='black', facecolors='white', s=100, label='Zero')

# برچسب‌های محور
ax.set_xlabel(r'$\mathbb{Re}$', fontsize=14)
ax.set_ylabel(r'$\mathbb{Im}$', fontsize=14)

# برچسب‌ها و تنظیمات
ax.text(-1.05, 0.05, '-1', fontsize=12)
ax.text(1/3 - 0.05, -0.1, r'$\frac{1}{3}$', fontsize=12)
ax.text(2 - 0.05, -0.1, '2', fontsize=12)
ax.text(3 - 0.05, -0.1, '3', fontsize=12)

# اضافه کردن توضیحات
ax.text(0.3, 1.1, 'Unit circle', fontsize=12)
ax.text(2.5, 2.5, 'X(z)', fontsize=12)
ax.text(3.5, -0.8, 'Figure P3.4', fontsize=12, fontweight='bold')

# تنظیمات نمایش
ax.set_xlim(-1.5, 3.5)
ax.set_ylim(-1.5, 1.5)
ax.set_aspect('equal')
ax.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ________________

# %% [markdown]
# 3.5.
#
# دنباله $ x[n] $ را با توجه به تبدیل $ Z $ آن تعیین کنید
#
# $$
# X(z) = (1 + 2z)(1 + 3z^{-1})(1 - z^{-1})
# $$
#
# $$
# = 2z + 5 - 4z^{-1} - 3z^{-2}
# $$
#
# $$
# = \sum_{n=-\infty}^{\infty} x[n] z^{-n}
# $$
#
# ,بنابراین
#
# $$
# x[n] = 2\delta[n+1] + 5\delta[n] - 4\delta[n-1] - 3\delta[n-2]
# $$
# ___________
# 3.6.
# <div dir="rtl" align="right">
#
# **چندین تبدیل \( z \) آورده شده‌اند. برای هرکدام، تبدیل معکوس \( z \) را با استفاده از هر دو روش—بسط کسرهای جزئی و بسط سری توانی—به‌دست آورید (مطابق بحث در بخش ۳.۳). علاوه بر این، مشخص کنید که آیا تبدیل فوریه در هر مورد وجود دارد یا خیر.**
#
# </div>
#
# ‏(d)
# ‏$$ X(z) = \frac{1 - \frac{1}{2}z^{-1}}{1 - \frac{1}{4}z^{-2}}, \quad |z| > \frac{1}{2} $$
#
# ‏(e)
# ‏$$ X(z) = \frac{1 - az^{-1}}{z^{-1} - a}, \quad |z| > |1/a| $$
#
#
# ______________
#
# ￼ :به‌صورت زیر داده شده است (d)
#
# $$
# X(z) = \frac{1 - \frac{1}{2}z^{-1}}{1 - \frac{1}{4}z^{-2}}, \quad |z| > \frac{1}{2}
# $$
#
# :تجزیه کسرها
#
# $$
# X(z) = \frac{1 - \frac{1}{2}z^{-1}}{1 - \frac{1}{4}z^{-2}} = \frac{1}{1 + \frac{1}{2}z^{-1}}, \quad |z| > \frac{1}{2}
# $$
# :
# دنباله زمانی
# $$
# x[n] = \left( -\frac{1}{2} \right)^n u[n]
# $$
#
#
# ￼ :به‌صورت زیر داده شده است (e)
#
# $$
# X(z) = \frac{1 - az^{-1}}{z^{-1} - a}, \quad |z| > |a^{-1}|
# $$
#
# :تجزیه کسرها
# $$
# X(z) = -a - \frac{a^{-1}(1 - a^2)}{1 - a^{-1}z^{-1}}, \quad |z| > |a^{-1}|
# $$
#
# :دنباله زمانی
# $$
# x[n] = -a\delta[n] - (1 - a^2)a^{-(n+1)} u[n]
# $$
#
# بنابراین،
# $$
# \Rightarrow x[n] = -a\delta[n] - (1 - a^2)a^{-(n+1)} u[n]
# $$
#
# _________________
